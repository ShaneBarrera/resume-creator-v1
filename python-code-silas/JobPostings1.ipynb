# %%
import pandas as pd

# Specify the columns to load
columns_to_load = ['Title', 'Company', 'Location', 'JobDescription', 
                   'JobRequirment', 'RequiredQual', 
                   'ApplicationP', 'AboutC']

# Load the data from the CSV file
df = pd.read_csv('../datasets/job_postings_1.csv', usecols=columns_to_load)
df
# Out:
#                                                    Title  \
# 0                                Chief Financial Officer
# 1      Full-time Community Connections Intern (paid i...
# 2                                    Country Coordinator
# 3                                         BCC Specialist
# 4                                     Software Developer
# ...                                                  ...
# 18996                    Senior Creative UX/ UI Designer
# 18997                       Category Development Manager
# 18998                      Operational Marketing Manager
# 18999                    Head of Online Sales Department
# 19000                         Lawyer in Legal Department
#
#                                                  Company  \
# 0                   AMERIA Investment Consulting Company
# 1        International Research & Exchanges Board (IREX)
# 2              Caucasus Environmental NGO Network (CENN)
# ...

# %%
# Concatenate each column into a single string
concatenated_series = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Convert the Series to a numpy array
arr = concatenated_series.to_numpy()
arr.size
# Out:
# 19001

# %%
# take an array of strings in python, make them all lowercase a-z and space characters only, then could how many times each word ocurs in the total corpus of text and display the results from most frequent to least frequent

import collections
import re

merged_string = ' '.join(arr)
clean_string = re.sub('[^a-z\s]', '', merged_string.lower())
clean_words = clean_string.split()
word_counts = collections.Counter(clean_words)
most_common_words = word_counts.most_common()

for word, count in most_common_words:
    print(word, count)
# Out:
# and 306745
# the 235311
# of 228439
# in 153108
# to 123593
# for 67377
# a 63557
# with 55177
# is 43079
# mention 41574
# please 41275
# armenia 38855
# knowledge 38818
# experience 36272
# your 33866
# be 33124
# skills 32941
# work 31782
# will 29977
# that 28383
# or 28230
# as 27082
# you 26761
# application 25685
# this 24235
# development 24155
# yerevan 24025
# letter 24022
# on 24013
# its 23453
# ability 23245
# through 23225
# center 22661
# english 22021
# website 21863
# career 20816
# job 20804
# clearly 20707
# opportunity 19738
# thanks 19328
# learned 19091
# wwwcareercenteram 19084
# url 18974
# are 18721
# at 18123
# management 17132
# armenian 16697
# candidates 16544
# project 15987
# other 15583
# all 15370
# by 15080
# excellent 14913
# an 14729
# software 14719
# good 14516
# team 14388
# email 14363
# position 14214
# company 14124
# office 13617
# nan 13556
# information 13377
# years 12467
# languages 12374
# communication 12290
# language 11869
# ...

# %%
# Modify the existing Python code to use the NLTK library and ensure the final list only displays nouns, verbs, and adjectives. All forms of a word should be considered the same word. word like 'run', 'runs', 'running'

import collections
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from tqdm import tqdm

nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

print('here 1')

merged_string = ' '.join(arr)
clean_string = re.sub('[^a-z\s]', '', merged_string.lower())
tokens = word_tokenize(clean_string)

print('here 2')

lemmatizer = WordNetLemmatizer() 
stop_words = set(stopwords.words('english')) 

print('here 3')

tagged_tokens = pos_tag(tokens)
filtered_words = []

print('here 4')

for word, tag in tqdm(tagged_tokens):
    if tag in ['NN', 'NNS', 'NNP', 'NNPS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'JJ', 'JJR', 'JJS']:
        lemmatized_word = lemmatizer.lemmatize(word)
        if lemmatized_word not in stop_words:
            filtered_words.append(lemmatized_word)

word_counts = collections.Counter(filtered_words)
most_common_words = word_counts.most_common()

for word, count in tqdm(most_common_words):
    print(word, count)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/silas/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/silas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# here 1
# here 2
# here 3
# here 4
# ...
# 100%|██████████| 31199/31199 [00:00<00:00, 151264.94it/s]
# mention 41577
# please 41118
# knowledge 38811
# experience 36147
# application 34527
# work 33600
# skill 33187
# armenia 32037
# letter 25277
# development 24643
# language 24243
# ability 24079
# project 23464
# center 23086
# website 22250
# english 21983
# job 21584
# yerevan 21509
# opportunity 21147
# career 20895
# company 19352
# thanks 19328
# learned 19091
# wwwcareercenteram 19084
# url 18984
# candidate 18698
# management 17183
# armenian 16947
# team 15948
# year 15664
# good 15525
# service 15343
# excellent 14913
# position 14871
# software 14764
# ...
