# %%
from docx import Document

document = Document()

document.add_paragraph('This is a paragraph.')
document.add_heading('Heading 1', level=1)
document.save('output.docx')

# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

document = Document()

# Personal Information
document.add_heading('Silas Raye', 0)
paragraph = document.add_paragraph('Email: silas.raye@gmail.com | Phone: 352-231-0747 \n')

# Education
document.add_heading('Education:', level=2)
document.add_paragraph('Bachelor\'s Degree in Data Science\nUniversity of Florida', style='Body Text')

# Technical Skills
document.add_heading('Technical Skills:', level=2)
skills = ['Data Analysis','Reporting','Analytics','MS Office Suite (Word, Excel, PowerPoint)','MS Visual Studio',
          'Data Management','Problem-Solving','Quantitative Skills','Analytical Abilities','Business Intelligence',
          'Report Writing','Data Visualization','Excel','Data Accuracy']
for skill in skills:
    document.add_paragraph(skill, style='List Bullet')

# Experience
document.add_heading('Experience:', level=2)

# Independent Projects
document.add_heading('Independent Projects:', level=2)

projects = {
    'Video Game Project (Boom + Bust Puzzle Game)': ['Developed a small video game demo for a puzzle game called Boom + Bust.',
                                                     'Demonstrated creative and problem-solving skills to create an engaging and enjoyable gaming experience.',
                                                     'Worked independently to design and implement game mechanics and features.'],

    'Sentiment Analysis for Predicting Dow Jones Movements': ['Conducted research and wrote a paper on using sentiment analysis and news headlines to predict the movements of the Dow Jones.',
                                                             'Demonstrated data analysis and quantitative skills in processing and interpreting data.',
                                                             'Achieved a simulation accuracy of 140% return on investment over one year, showcasing strong analytical abilities.'],

    'Resume Creation Program': ['Collaborated in a small team to develop a resume creation program.',
                               'Utilized MS Visual Studio and programming skills to build the program.',
                               'Successfully launched the program, gaining a small user base, and displaying effective teamwork and collaboration.']
}

for project, descriptions in projects.items():
    document.add_heading(project, level=3)
    for desc in descriptions:
        document.add_paragraph(desc, style='BodyText')

# Employment History
document.add_heading('Employment History:', level=2)
document.add_paragraph("Satchel’s Pizza | 2018 - Present", style='Body Text')

roles = {
    'Graphic Designer': ['Designed marketing materials using Adobe Illustrator and Photoshop to enhance the restaurant\'s brand image.',
                         'Ensured easy-to-understand communication of promotions and deals to customers.'],
    'Waiter': ['Provided excellent customer service, ensuring a positive dining experience for guests.',
               'Demonstrated strong communication and collaboration skills while working with the restaurant team.'],
    'Cashier': ['Handled transactions accurately and efficiently, showcasing attention to detail and data accuracy.'],
    'Host': ['Managed restaurant reservations and seating arrangements, displaying organizational skills.'],
    'Soda Maker': ['Handled the preparation and presentation of beverages, ensuring high-quality service.']
}

for role, descriptions in roles.items():
    document.add_heading(role, level=3)
    for desc in descriptions:
        document.add_paragraph(desc, style='Body Text')

# Certifications & Training
document.add_heading('Certifications & Training:', level=2)
document.add_paragraph('Certified in Adobe and Microsoft Suites\nProficient in the Google Suite', style='Body Text')

# Additional Skills
document.add_heading('Additional Skills:', level=2)
skills = ['Enthusiastic and Creative', 'Organized and Detail-Oriented', 'Team Player with Strong Collaboration and Delegation Skills']
for skill in skills:
    document.add_paragraph(skill, style='Body Text')

# Note
document.add_paragraph('Note: This resume highlights Silas Raye\'s education, technical skills, independent projects, and employment history, while incorporating as many of the specified skill words as possible to showcase his qualifications for STEM-related positions.', style='BodyText')

document.save('output1.docx')
